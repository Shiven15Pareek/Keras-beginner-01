# %% [markdown]
# <a href="https://colab.research.google.com/github/Shiven15Pareek/Keras-beginner-01/blob/main/Regression_keras_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("Admission_Predict.csv")
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
df.drop(columns=['Serial No.'],axis=1,inplace=True)

# %%
x=df.drop(columns=['Chance of Admit '],axis=1)
y=df['Chance of Admit ']

# %%
df.isnull().sum()
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
x.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x_scaled=scaler.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (320, 7)

# %% [markdown]
# **MODEL CREATION
# **

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
model=Sequential([
    Dense(9,activation='relu',input_dim=7),
    Dense(4,activation='relu'),
    Dense(3,activation='relu'),
    Dense(1,activation='linear')
])
model.compile(loss='mean_squared_error',optimizer='adam')
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.fit(x_train,y_train,epochs=100,validation_split=0.1)
# Out:
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.3083 - val_loss: 0.2835
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2405 - val_loss: 0.2101
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1652 - val_loss: 0.1371
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1060 - val_loss: 0.0811
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0649 - val_loss: 0.0446
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0363 - val_loss: 0.0246
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0204 - val_loss: 0.0170
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0148 - val_loss: 0.0159
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0143 - val_loss: 0.0149
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0136 - val_loss: 0.0131
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0129 - val_loss: 0.0111
# Epoch 12/100
# ...

# %%
y_pred=model.predict(x_test)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step

# %%
y_pred
# Out:
# array([[0.68408823],
#        [0.7877658 ],
#        [0.9796914 ],
#        [0.81010294],
#        [0.6506544 ],
#        [0.9638812 ],
#        [0.50625074],
#        [0.5334154 ],
#        [0.6534709 ],
#        [0.8290561 ],
#        [0.71919197],
#        [0.92932504],
#        [0.5780134 ],
#        [0.8777051 ],
#        [0.7226844 ],
#        [0.6752682 ],
#        [0.6983084 ],
#        [0.4800124 ],
#        [0.7042071 ],
#        [0.9862608 ],
#        [0.5861968 ],
#        [0.6635767 ],
#        [0.7277593 ],
#        [0.50954896],
#        [0.9618786 ],
#        [0.8026062 ],
#        [0.67310613],
#        [0.5572975 ],
#        [0.65869534],
#        [0.8090784 ],
#        [0.79537356],
#        [0.964816  ],
#        [0.64473236],
#        [0.51519597],
#        [0.6697838 ],
#        [0.7007668 ],
#        [0.6728434 ],
#        [0.6558529 ],
#        [0.59685683],
#        [0.9048439 ],
#        [0.71688306],
#        [0.60396105],
#        [0.78016937],
# ...

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.7869905848703889
